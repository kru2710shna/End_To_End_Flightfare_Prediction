# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.11/site-packages (1.2.2)
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.5.0-cp311-cp311-macosx_12_0_arm64.whl (11.0 MB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scikit-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikit-learn-1.5.0 threadpoolctl-3.5.0

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Dataset
data = pd.read_excel("/Users/krushna/Downloads/data-42/Data_Train.xlsx")
pd.set_option("display.max_columns", None)

# %%
data.head()
data['Destination'].value_counts()
# Out:
# Destination
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
# Missing Values 
data.isnull().mean()
# Out:
# Airline            0.000000
# Date_of_Journey    0.000000
# Source             0.000000
# Destination        0.000000
# Route              0.000094
# Dep_Time           0.000000
# Arrival_Time       0.000000
# Duration           0.000000
# Total_Stops        0.000094
# Additional_Info    0.000000
# Price              0.000000
# dtype: float64

# %%
## There are very less missing values 
#We can use CCA
data.dropna(inplace= True)

# %%
data.shape
# Out:
# (10682, 11)

# %%
#Cleaning the data for Date_of_Journey
print(data['Date_of_Journey'])
# Out:
# 0        24/03/2019
# 1         1/05/2019
# 2         9/06/2019
# 3        12/05/2019
# 4        01/03/2019
#             ...
# 10678     9/04/2019
# 10679    27/04/2019
# 10680    27/04/2019
# 10681    01/03/2019
# 10682     9/05/2019
# Name: Date_of_Journey, Length: 10682, dtype: object

# %%
data['Day_of_Journey'] = pd.to_datetime(data.Date_of_Journey, format="%d/%m/%Y").dt.day

# %%
data['Month_of_Journey'] = pd.to_datetime(data["Date_of_Journey"], format = "%d/%m/%Y").dt.month

# %%
data['Year_of_Journey'] = pd.to_datetime(data["Date_of_Journey"], format = "%d/%m/%Y").dt.year

# %%
data.drop(['Date_of_Journey'], axis=1 , inplace = True)

# %%
data.tail(20)
# Out:
#                  Airline    Source Destination                  Route  \
# 10663        Jet Airways     Delhi      Cochin  DEL → JAI → BOM → COK
# 10664             IndiGo  Banglore       Delhi              BLR → DEL
# 10665             IndiGo   Kolkata    Banglore              CCU → BLR
# 10666        Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 10667        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 10668        Jet Airways     Delhi      Cochin  DEL → JDH → BOM → COK
# 10669          Air India     Delhi      Cochin        DEL → BOM → COK
# 10670          Air India   Kolkata    Banglore  CCU → IXR → DEL → BLR
# 10671          Air India    Mumbai   Hyderabad              BOM → HYD
# 10672        Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK
# 10673        Jet Airways     Delhi      Cochin  DEL → AMD → BOM → COK
# 10674        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 10675          Air India    Mumbai   Hyderabad              BOM → HYD
# 10676  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
# 10677           SpiceJet  Banglore       Delhi              BLR → DEL
# 10678           Air Asia   Kolkata    Banglore              CCU → BLR
# 10679          Air India   Kolkata    Banglore              CCU → BLR
# 10680        Jet Airways  Banglore       Delhi              BLR → DEL
# 10681            Vistara  Banglore   New Delhi              BLR → DEL
# 10682          Air India     Delhi      Cochin  DEL → GOI → BOM → COK
#
#       Dep_Time  Arrival_Time Duration Total_Stops  \
# 10663    19:30  12:35 07 Jun   17h 5m     2 stops
# 10664    18:55         21:50   2h 55m    non-stop
# 10665    15:15         17:45   2h 30m    non-stop
# 10666    18:15  19:00 13 Jun  24h 45m      1 stop
# 10667    22:55  20:20 13 Mar  21h 25m      1 stop
# 10668    11:40         19:00   7h 20m     2 stops
# 10669    08:00         19:15  11h 15m      1 stop
# 10670    05:50         23:15  17h 25m     2 stops
# 10671    21:05         22:25   1h 20m    non-stop
# 10672    23:05  19:00 28 Jun  19h 55m     2 stops
# 10673    13:25  04:25 28 May      15h     2 stops
# 10674    20:35  21:20 13 Mar  24h 45m      1 stop
# 10675    06:20         07:40   1h 20m    non-stop
# 10676    10:20         19:00   8h 40m      1 stop
# 10677    05:55         08:35   2h 40m    non-stop
# 10678    19:55         22:25   2h 30m    non-stop
# 10679    20:45         23:20   2h 35m    non-stop
# 10680    08:20         11:20       3h    non-stop
# 10681    11:30         14:10   2h 40m    non-stop
# 10682    10:55         19:15   8h 20m     2 stops
#
#                     Additional_Info  Price  Day_of_Journey  Month_of_Journey  \
# 10663   In-flight meal not included  11733               6                 6
# 10664                       No info   4823               9                 4
# 10665                       No info   4804              27                 4
# 10666   In-flight meal not included  10262              12                 6
# 10667   In-flight meal not included  11087              12                 3
# 10668                       No info  21219               9                 5
# 10669                       No info   9929              15                 6
# 10670                       No info  11411              12                 5
# 10671                       No info   3100               6                 6
# 10672   In-flight meal not included  11150              27                 6
# 10673                       No info  16704              27                 5
# 10674   In-flight meal not included  11087              12                 3
# 10675                       No info   3100               9                 6
# 10676                       No info   9794               1                 5
# 10677  No check-in baggage included   3257              21                 5
# 10678                       No info   4107               9                 4
# 10679                       No info   4145              27                 4
# 10680                       No info   7229              27                 4
# 10681                       No info  12648               1                 3
# 10682                       No info  11753               9                 5
#
#        Year_of_Journey
# 10663             2019
# 10664             2019
# 10665             2019
# 10666             2019
# 10667             2019
# 10668             2019
# 10669             2019
# 10670             2019
# 10671             2019
# 10672             2019
# 10673             2019
# 10674             2019
# 10675             2019
# 10676             2019
# 10677             2019
# 10678             2019
# 10679             2019
# 10680             2019
# 10681             2019
# 10682             2019

# %%
# Cleaning data for Dep_Time
print(data['Dep_Time'])
# Out:
# 0        22:20
# 1        05:50
# 2        09:25
# 3        18:05
# 4        16:50
#          ...
# 10678    19:55
# 10679    20:45
# 10680    08:20
# 10681    11:30
# 10682    10:55
# Name: Dep_Time, Length: 10682, dtype: object

# %%
data['Dep_min'] = pd.to_datetime(data.Dep_Time).dt.minute
# Out:
# /var/folders/6y/8rwnfv1s3855864m6xpflvj00000gn/T/ipykernel_6635/2886607276.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Dep_min'] = pd.to_datetime(data.Dep_Time).dt.minute

# %%
data['Dep_hour'] = pd.to_datetime(data.Dep_Time).dt.hour
# Out:
# /var/folders/6y/8rwnfv1s3855864m6xpflvj00000gn/T/ipykernel_6635/855346756.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Dep_hour'] = pd.to_datetime(data.Dep_Time).dt.hour

# %%
data.drop(['Dep_Time'], axis=1 , inplace = True)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  Day_of_Journey  \
# 0   2h 50m    non-stop         No info   3897              24
# 1   7h 25m     2 stops         No info   7662               1
# 2      19h     2 stops         No info  13882               9
# 3   5h 25m      1 stop         No info   6218              12
# 4   4h 45m      1 stop         No info  13302               1
#
#    Month_of_Journey  Year_of_Journey  Dep_min  Dep_hour
# 0                 3             2019       20        22
# 1                 5             2019       50         5
# 2                 6             2019       25         9
# 3                 5             2019        5        18
# 4                 3             2019       50        16

# %%
# Cleaning data for Arrival_Time
print(data['Arrival_Time'])
# Out:
# 0        01:10 22 Mar
# 1               13:15
# 2        04:25 10 Jun
# 3               23:30
# 4               21:35
#              ...
# 10678           22:25
# 10679           23:20
# 10680           11:20
# 10681           14:10
# 10682           19:15
# Name: Arrival_Time, Length: 10682, dtype: object

# %%
data['Arr_minute'] = pd.to_datetime(data.Arrival_Time).dt.minute
# Out:
# /var/folders/6y/8rwnfv1s3855864m6xpflvj00000gn/T/ipykernel_6635/2851061601.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Arr_minute'] = pd.to_datetime(data.Arrival_Time).dt.minute

# %%
data['Arr_hour'] = pd.to_datetime(data.Arrival_Time).dt.hour
# Out:
# /var/folders/6y/8rwnfv1s3855864m6xpflvj00000gn/T/ipykernel_6635/4185362245.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Arr_hour'] = pd.to_datetime(data.Arrival_Time).dt.hour

# %%
data.drop(['Arrival_Time'], axis=1 , inplace = True)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Day_of_Journey  Month_of_Journey  \
# 0    non-stop         No info   3897              24                 3
# 1     2 stops         No info   7662               1                 5
# 2     2 stops         No info  13882               9                 6
# 3      1 stop         No info   6218              12                 5
# 4      1 stop         No info  13302               1                 3
#
#    Year_of_Journey  Dep_min  Dep_hour  Arr_minute  Arr_hour
# 0             2019       20        22          10         1
# 1             2019       50         5          15        13
# 2             2019       25         9          25         4
# 3             2019        5        18          30        23
# 4             2019       50        16          35        21

# %%
# Cleaning data for Duration

duration = list(data['Duration'])
for i in range(len(duration)):
    if len(duration[i].split()) != 2: # If value != 2h 0m OR 0h 2m 
        if 'h' in duration[i]:
            duration[i] = duration[i].strip() + " 0m"
        else:
            duration[i] = "0h " + duration[i].strip() 

duration_hours = []
duration_minute = []

for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = 'h')[0]))
    duration_minute.append(int(duration[i].split(sep = 'm')[0].split()[-1]))        

data['duration_hours']= duration_hours
data['duration_minute'] = duration_minute
data.drop('Duration', axis =1 , inplace= True)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
#
#   Additional_Info  Price  Day_of_Journey  Month_of_Journey  Year_of_Journey  \
# 0         No info   3897              24                 3             2019
# 1         No info   7662               1                 5             2019
# 2         No info  13882               9                 6             2019
# 3         No info   6218              12                 5             2019
# 4         No info  13302               1                 3             2019
#
#    Dep_min  Dep_hour  Arr_minute  Arr_hour  duration_hours  duration_minute
# 0       20        22          10         1               2               50
# 1       50         5          15        13               7               25
# 2       25         9          25         4              19                0
# 3        5        18          30        23               5               25
# 4       50        16          35        21               4               45

# %%
# cleaning categorical data which is Airline 
data['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
# Removing jet airways beacause it's no more there 
data = data[data['Airline'] != 'Jet Airways']
# Removing jet airways beacause it's no more there 
data = data[data['Airline'] != 'Jet Airways Business']

# %%
data
# Out:
#          Airline    Source Destination                  Route Total_Stops  \
# 0         IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1      Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 3         IndiGo   Kolkata    Banglore        CCU → NAG → BLR      1 stop
# 4         IndiGo  Banglore   New Delhi        BLR → NAG → DEL      1 stop
# 5       SpiceJet   Kolkata    Banglore              CCU → BLR    non-stop
# ...          ...       ...         ...                    ...         ...
# 10677   SpiceJet  Banglore       Delhi              BLR → DEL    non-stop
# 10678   Air Asia   Kolkata    Banglore              CCU → BLR    non-stop
# 10679  Air India   Kolkata    Banglore              CCU → BLR    non-stop
# 10681    Vistara  Banglore   New Delhi              BLR → DEL    non-stop
# 10682  Air India     Delhi      Cochin  DEL → GOI → BOM → COK     2 stops
#
#                     Additional_Info  Price  Day_of_Journey  Month_of_Journey  \
# 0                           No info   3897              24                 3
# 1                           No info   7662               1                 5
# 3                           No info   6218              12                 5
# 4                           No info  13302               1                 3
# 5                           No info   3873              24                 6
# ...                             ...    ...             ...               ...
# 10677  No check-in baggage included   3257              21                 5
# 10678                       No info   4107               9                 4
# 10679                       No info   4145              27                 4
# 10681                       No info  12648               1                 3
# 10682                       No info  11753               9                 5
#
#        Year_of_Journey  Dep_min  Dep_hour  Arr_minute  Arr_hour  \
# 0                 2019       20        22          10         1
# 1                 2019       50         5          15        13
# 3                 2019        5        18          30        23
# 4                 2019       50        16          35        21
# 5                 2019        0         9          25        11
# ...                ...      ...       ...         ...       ...
# 10677             2019       55         5          35         8
# 10678             2019       55        19          25        22
# 10679             2019       45        20          20        23
# 10681             2019       30        11          10        14
# 10682             2019       55        10          15        19
#
#        duration_hours  duration_minute
# 0                   2               50
# 1                   7               25
# 3                   5               25
# 4                   4               45
# 5                   2               25
# ...               ...              ...
# 10677               2               40
# 10678               2               30
# 10679               2               35
# 10681               2               40
# 10682               8               20
#
# [6827 rows x 16 columns]

# %%
# Plot separate histograms for each airline
airlines = data['Airline'].unique()
n_airlines = len(airlines)

plt.figure(figsize=(15, 10))
for i, airline in enumerate(airlines, 1):
    plt.subplot((n_airlines // 3) + 1, 3, i)
    plt.hist(data[data['Airline'] == airline]['Price'], bins=10, color='blue', edgecolor='black')
    plt.title(airline)
    plt.xlabel('Price')
    plt.ylabel('Frequency')
    plt.tight_layout()

plt.suptitle('Histogram of Prices by Airline', y=1.02)
plt.tight_layout()
plt.show()

# %%
# OnHot Encoding for categorical data and therfore which are Nominal Value
Airline = data[['Airline']]
Airline = pd.get_dummies(Airline, drop_first = False )
Airline.head()
# Out:
#    Airline_Air Asia  Airline_Air India  Airline_GoAir  Airline_IndiGo  \
# 0             False              False          False            True
# 1             False               True          False           False
# 3             False              False          False            True
# 4             False              False          False            True
# 5             False              False          False           False
#
#    Airline_Multiple carriers  Airline_Multiple carriers Premium economy  \
# 0                      False                                      False
# 1                      False                                      False
# 3                      False                                      False
# 4                      False                                      False
# 5                      False                                      False
#
#    Airline_SpiceJet  Airline_Trujet  Airline_Vistara  \
# 0             False           False            False
# 1             False           False            False
# 3             False           False            False
# 4             False           False            False
# 5              True           False            False
#
#    Airline_Vistara Premium economy
# 0                            False
# 1                            False
# 3                            False
# 4                            False
# 5                            False

# %%
# Categorical value cleaning which is source
data['Source'].value_counts()
# Out:
# Source
# Delhi       2948
# Kolkata     1615
# Banglore    1405
# Mumbai       478
# Chennai      381
# Name: count, dtype: int64

# %%
# Changing name to make it easy 
df = data

# %%
# Plot separate histograms for each source
airlines = df['Source'].unique()
n_airlines = len(airlines)

plt.figure(figsize=(15, 10))
for i, airline in enumerate(airlines, 1):
    plt.subplot((n_airlines // 3) + 1, 3, i)
    plt.hist(df[df['Source'] == airline]['Price'], bins=10, color='blue', edgecolor='black')
    plt.title(airline)
    plt.xlabel('Price')
    plt.ylabel('Frequency')
    plt.tight_layout()

plt.suptitle('Histogram of Prices by Source', y=1.02)
plt.tight_layout()
plt.show()

# %%
# OnHot Encoding for categorical data and therfore which are Nominal Value
Source = df[['Source']]
Source = pd.get_dummies(Source, drop_first = False )
Source.head()
# Out:
#    Source_Banglore  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0             True           False         False           False
# 1            False           False         False            True
# 3            False           False         False            True
# 4             True           False         False           False
# 5            False           False         False            True
#
#    Source_Mumbai
# 0          False
# 1          False
# 3          False
# 4          False
# 5          False

# %%
# Cleaning another categorical feature Destintion
df['Destination'].value_counts()
# Out:
# Destination
# Cochin       2948
# Banglore     1615
# Delhi         895
# New Delhi     510
# Hyderabad     478
# Kolkata       381
# Name: count, dtype: int64

# %%
# OnHot Encoding for categorical data and therfore which are Nominal Value
Destination = df[['Destination']]
Destination = pd.get_dummies(Destination, drop_first = False )
Destination.head()
# Out:
#    Destination_Banglore  Destination_Cochin  Destination_Delhi  \
# 0                 False               False              False
# 1                  True               False              False
# 3                  True               False              False
# 4                 False               False              False
# 5                  True               False              False
#
#    Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi
# 0                  False                False                   True
# 1                  False                False                  False
# 3                  False                False                  False
# 4                  False                False                   True
# 5                  False                False                  False

# %%
# W'll drop routes
df.drop('Route', axis=1, inplace= True)

# %%
df.drop('Additional_Info', axis=1, inplace= True)

# %%
df
# Out:
#          Airline    Source Destination Total_Stops  Price  Day_of_Journey  \
# 0         IndiGo  Banglore   New Delhi    non-stop   3897              24
# 1      Air India   Kolkata    Banglore     2 stops   7662               1
# 3         IndiGo   Kolkata    Banglore      1 stop   6218              12
# 4         IndiGo  Banglore   New Delhi      1 stop  13302               1
# 5       SpiceJet   Kolkata    Banglore    non-stop   3873              24
# ...          ...       ...         ...         ...    ...             ...
# 10677   SpiceJet  Banglore       Delhi    non-stop   3257              21
# 10678   Air Asia   Kolkata    Banglore    non-stop   4107               9
# 10679  Air India   Kolkata    Banglore    non-stop   4145              27
# 10681    Vistara  Banglore   New Delhi    non-stop  12648               1
# 10682  Air India     Delhi      Cochin     2 stops  11753               9
#
#        Month_of_Journey  Year_of_Journey  Dep_min  Dep_hour  Arr_minute  \
# 0                     3             2019       20        22          10
# 1                     5             2019       50         5          15
# 3                     5             2019        5        18          30
# 4                     3             2019       50        16          35
# 5                     6             2019        0         9          25
# ...                 ...              ...      ...       ...         ...
# 10677                 5             2019       55         5          35
# 10678                 4             2019       55        19          25
# 10679                 4             2019       45        20          20
# 10681                 3             2019       30        11          10
# 10682                 5             2019       55        10          15
#
#        Arr_hour  duration_hours  duration_minute
# 0             1               2               50
# 1            13               7               25
# 3            23               5               25
# 4            21               4               45
# 5            11               2               25
# ...         ...             ...              ...
# 10677         8               2               40
# 10678        22               2               30
# 10679        23               2               35
# 10681        14               2               40
# 10682        19               8               20
#
# [6827 rows x 14 columns]

# %%
# Take another categorical variable called Total_Stops
df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      3086
# non-stop    2868
# 2 stops      827
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
# Ordinal Category = Label Encoder 
df.replace({"1 stop" : 1 , "non-stop": 0 , "2 stops": 2 , "3 stops" : 3 , "4 stops" : 4}, inplace= True)

# %%
train_data = pd.concat([df, Source, Destination, Airline], axis=1)

# %%
train_data
# Out:
#          Airline    Source Destination  Total_Stops  Price  Day_of_Journey  \
# 0         IndiGo  Banglore   New Delhi            0   3897              24
# 1      Air India   Kolkata    Banglore            2   7662               1
# 3         IndiGo   Kolkata    Banglore            1   6218              12
# 4         IndiGo  Banglore   New Delhi            1  13302               1
# 5       SpiceJet   Kolkata    Banglore            0   3873              24
# ...          ...       ...         ...          ...    ...             ...
# 10677   SpiceJet  Banglore       Delhi            0   3257              21
# 10678   Air Asia   Kolkata    Banglore            0   4107               9
# 10679  Air India   Kolkata    Banglore            0   4145              27
# 10681    Vistara  Banglore   New Delhi            0  12648               1
# 10682  Air India     Delhi      Cochin            2  11753               9
#
#        Month_of_Journey  Year_of_Journey  Dep_min  Dep_hour  Arr_minute  \
# 0                     3             2019       20        22          10
# 1                     5             2019       50         5          15
# 3                     5             2019        5        18          30
# 4                     3             2019       50        16          35
# 5                     6             2019        0         9          25
# ...                 ...              ...      ...       ...         ...
# 10677                 5             2019       55         5          35
# 10678                 4             2019       55        19          25
# 10679                 4             2019       45        20          20
# 10681                 3             2019       30        11          10
# 10682                 5             2019       55        10          15
#
#        Arr_hour  duration_hours  duration_minute  Source_Banglore  \
# 0             1               2               50             True
# 1            13               7               25            False
# 3            23               5               25            False
# 4            21               4               45             True
# 5            11               2               25            False
# ...         ...             ...              ...              ...
# 10677         8               2               40             True
# 10678        22               2               30            False
# 10679        23               2               35            False
# 10681        14               2               40             True
# 10682        19               8               20            False
#
#        Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai  \
# 0               False         False           False          False
# 1               False         False            True          False
# 3               False         False            True          False
# 4               False         False           False          False
# 5               False         False            True          False
# ...               ...           ...             ...            ...
# 10677           False         False           False          False
# 10678           False         False            True          False
# 10679           False         False            True          False
# 10681           False         False           False          False
# 10682           False          True           False          False
#
#        Destination_Banglore  Destination_Cochin  Destination_Delhi  \
# 0                     False               False              False
# 1                      True               False              False
# 3                      True               False              False
# 4                     False               False              False
# 5                      True               False              False
# ...                     ...                 ...                ...
# 10677                 False               False               True
# 10678                  True               False              False
# 10679                  True               False              False
# 10681                 False               False              False
# 10682                 False                True              False
#
#        Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi  \
# 0                      False                False                   True
# 1                      False                False                  False
# 3                      False                False                  False
# 4                      False                False                   True
# 5                      False                False                  False
# ...                      ...                  ...                    ...
# 10677                  False                False                  False
# 10678                  False                False                  False
# 10679                  False                False                  False
# 10681                  False                False                   True
# 10682                  False                False                  False
#
#        Airline_Air Asia  Airline_Air India  Airline_GoAir  Airline_IndiGo  \
# 0                 False              False          False            True
# 1                 False               True          False           False
# 3                 False              False          False            True
# 4                 False              False          False            True
# 5                 False              False          False           False
# ...                 ...                ...            ...             ...
# 10677             False              False          False           False
# 10678              True              False          False           False
# 10679             False               True          False           False
# 10681             False              False          False           False
# 10682             False               True          False           False
#
#        Airline_Multiple carriers  Airline_Multiple carriers Premium economy  \
# 0                          False                                      False
# 1                          False                                      False
# 3                          False                                      False
# 4                          False                                      False
# 5                          False                                      False
# ...                          ...                                        ...
# 10677                      False                                      False
# 10678                      False                                      False
# 10679                      False                                      False
# 10681                      False                                      False
# 10682                      False                                      False
#
#        Airline_SpiceJet  Airline_Trujet  Airline_Vistara  \
# 0                 False           False            False
# 1                 False           False            False
# 3                 False           False            False
# 4                 False           False            False
# 5                  True           False            False
# ...                 ...             ...              ...
# 10677              True           False            False
# 10678             False           False            False
# 10679             False           False            False
# 10681             False           False             True
# 10682             False           False            False
#
#        Airline_Vistara Premium economy
# 0                                False
# 1                                False
# 3                                False
# 4                                False
# 5                                False
# ...                                ...
# 10677                            False
# 10678                            False
# 10679                            False
# 10681                            False
# 10682                            False
#
# [6827 rows x 35 columns]

# %%
train_data.drop(['Airline', 'Source', 'Destination'], axis=1,inplace=True)

# %%
train_data
# Out:
#        Total_Stops  Price  Day_of_Journey  Month_of_Journey  Year_of_Journey  \
# 0                0   3897              24                 3             2019
# 1                2   7662               1                 5             2019
# 3                1   6218              12                 5             2019
# 4                1  13302               1                 3             2019
# 5                0   3873              24                 6             2019
# ...            ...    ...             ...               ...              ...
# 10677            0   3257              21                 5             2019
# 10678            0   4107               9                 4             2019
# 10679            0   4145              27                 4             2019
# 10681            0  12648               1                 3             2019
# 10682            2  11753               9                 5             2019
#
#        Dep_min  Dep_hour  Arr_minute  Arr_hour  duration_hours  \
# 0           20        22          10         1               2
# 1           50         5          15        13               7
# 3            5        18          30        23               5
# 4           50        16          35        21               4
# 5            0         9          25        11               2
# ...        ...       ...         ...       ...             ...
# 10677       55         5          35         8               2
# 10678       55        19          25        22               2
# 10679       45        20          20        23               2
# 10681       30        11          10        14               2
# 10682       55        10          15        19               8
#
#        duration_minute  Source_Banglore  Source_Chennai  Source_Delhi  \
# 0                   50             True           False         False
# 1                   25            False           False         False
# 3                   25            False           False         False
# 4                   45             True           False         False
# 5                   25            False           False         False
# ...                ...              ...             ...           ...
# 10677               40             True           False         False
# 10678               30            False           False         False
# 10679               35            False           False         False
# 10681               40             True           False         False
# 10682               20            False           False          True
#
#        Source_Kolkata  Source_Mumbai  Destination_Banglore  \
# 0               False          False                 False
# 1                True          False                  True
# 3                True          False                  True
# 4               False          False                 False
# 5                True          False                  True
# ...               ...            ...                   ...
# 10677           False          False                 False
# 10678            True          False                  True
# 10679            True          False                  True
# 10681           False          False                 False
# 10682           False          False                 False
#
#        Destination_Cochin  Destination_Delhi  Destination_Hyderabad  \
# 0                   False              False                  False
# 1                   False              False                  False
# 3                   False              False                  False
# 4                   False              False                  False
# 5                   False              False                  False
# ...                   ...                ...                    ...
# 10677               False               True                  False
# 10678               False              False                  False
# 10679               False              False                  False
# 10681               False              False                  False
# 10682                True              False                  False
#
#        Destination_Kolkata  Destination_New Delhi  Airline_Air Asia  \
# 0                    False                   True             False
# 1                    False                  False             False
# 3                    False                  False             False
# 4                    False                   True             False
# 5                    False                  False             False
# ...                    ...                    ...               ...
# 10677                False                  False             False
# 10678                False                  False              True
# 10679                False                  False             False
# 10681                False                   True             False
# 10682                False                  False             False
#
#        Airline_Air India  Airline_GoAir  Airline_IndiGo  \
# 0                  False          False            True
# 1                   True          False           False
# 3                  False          False            True
# 4                  False          False            True
# 5                  False          False           False
# ...                  ...            ...             ...
# 10677              False          False           False
# 10678              False          False           False
# 10679               True          False           False
# 10681              False          False           False
# 10682               True          False           False
#
#        Airline_Multiple carriers  Airline_Multiple carriers Premium economy  \
# 0                          False                                      False
# 1                          False                                      False
# 3                          False                                      False
# 4                          False                                      False
# 5                          False                                      False
# ...                          ...                                        ...
# 10677                      False                                      False
# 10678                      False                                      False
# 10679                      False                                      False
# 10681                      False                                      False
# 10682                      False                                      False
#
#        Airline_SpiceJet  Airline_Trujet  Airline_Vistara  \
# 0                 False           False            False
# 1                 False           False            False
# 3                 False           False            False
# 4                 False           False            False
# 5                  True           False            False
# ...                 ...             ...              ...
# 10677              True           False            False
# 10678             False           False            False
# 10679             False           False            False
# 10681             False           False             True
# 10682             False           False            False
#
#        Airline_Vistara Premium economy
# 0                                False
# 1                                False
# 3                                False
# 4                                False
# 5                                False
# ...                                ...
# 10677                            False
# 10678                            False
# 10679                            False
# 10681                            False
# 10682                            False
#
# [6827 rows x 32 columns]

# %% [markdown]
# # Test Data

# %%
test_data = pd.read_excel("/Users/krushna/Downloads/data-42/Test_set.xlsx")

# %%
test_data.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
# Preprocessing

print("Test data Info")
print("-"*75)
print(test_data.info())

print()
print()

print("Null values :")
print("-"*75)
test_data.dropna(inplace = True)
print(test_data.isnull().sum())

# EDA

# Date_of_Journey
test_data["Journey_day"] = pd.to_datetime(test_data.Date_of_Journey, format="%d/%m/%Y").dt.day
test_data["Journey_month"] = pd.to_datetime(test_data["Date_of_Journey"], format = "%d/%m/%Y").dt.month
test_data.drop(["Date_of_Journey"], axis = 1, inplace = True)

# Dep_Time
test_data["Dep_hour"] = pd.to_datetime(test_data["Dep_Time"]).dt.hour
test_data["Dep_min"] = pd.to_datetime(test_data["Dep_Time"]).dt.minute
test_data.drop(["Dep_Time"], axis = 1, inplace = True)

# Arrival_Time
test_data["Arrival_hour"] = pd.to_datetime(test_data.Arrival_Time).dt.hour
test_data["Arrival_min"] = pd.to_datetime(test_data.Arrival_Time).dt.minute
test_data.drop(["Arrival_Time"], axis = 1, inplace = True)

# Duration
duration = list(test_data["Duration"])

for i in range(len(duration)):
    if len(duration[i].split()) != 2:    # Check if duration contains only hour or mins
        if "h" in duration[i]:
            duration[i] = duration[i].strip() + " 0m"   # Adds 0 minute
        else:
            duration[i] = "0h " + duration[i]           # Adds 0 hour

duration_hours = []
duration_mins = []
for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = "h")[0]))    # Extract hours from duration
    duration_mins.append(int(duration[i].split(sep = "m")[0].split()[-1]))   # Extracts only minutes from duration

# Adding Duration column to test set
test_data["Duration_hours"] = duration_hours
test_data["Duration_mins"] = duration_mins
test_data.drop(["Duration"], axis = 1, inplace = True)

# Airline 
# Removing jet airways beacause it's no more there 
test_data = test_data[test_data['Airline'] != 'Jet Airways']
# Removing jet airways beacause it's no more there 
test_data= test_data[test_data['Airline'] != 'Jet Airways Business']
# Categorical data

print("Airline")
print("-"*75)
print(test_data["Airline"].value_counts())
Airline = pd.get_dummies(test_data["Airline"], drop_first= False)

print()

print("Source")
print("-"*75)
print(test_data["Source"].value_counts())
Source = pd.get_dummies(test_data["Source"], drop_first= False)

print()

print("Destination")
print("-"*75)
print(test_data["Destination"].value_counts())
Destination = pd.get_dummies(test_data["Destination"], drop_first = False)

# Additional_Info contains almost 80% no_info
# Route and Total_Stops are related to each other
test_data.drop(["Route", "Additional_Info"], axis = 1, inplace = True)

# Replacing Total_Stops
test_data.replace({"non-stop": 0, "1 stop": 1, "2 stops": 2, "3 stops": 3, "4 stops": 4}, inplace = True)

# Concatenate dataframe --> test_data + Airline + Source + Destination
data_test = pd.concat([test_data, Airline, Source, Destination], axis = 1)

data_test.drop(["Airline", "Source", "Destination"], axis = 1, inplace = True)

print()
print()

print("Shape of test data : ", data_test.shape)
# Out:
# Test data Info
# ---------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB
# None
#
#
# Null values :
# ---------------------------------------------------------------------------
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64
# Airline
# ---------------------------------------------------------------------------
# Airline
# IndiGo                               511
# Air India                            440
# Multiple carriers                    347
# SpiceJet                             208
# Vistara                              129
# Air Asia                              86
# GoAir                                 46
# Multiple carriers Premium economy      3
# Vistara Premium economy                2
# Name: count, dtype: int64
#
# Source
# ---------------------------------------------------------------------------
# Source
# Delhi       800
# Kolkata     406
# Banglore    355
# Mumbai      136
# Chennai      75
# Name: count, dtype: int64
#
# Destination
# ---------------------------------------------------------------------------
# Destination
# Cochin       800
# Banglore     406
# Delhi        226
# Hyderabad    136
# New Delhi    129
# Kolkata       75
# Name: count, dtype: int64
#
#
# Shape of test data :  (1772, 29)
# /var/folders/6y/8rwnfv1s3855864m6xpflvj00000gn/T/ipykernel_6635/2632046671.py:23: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test_data["Dep_hour"] = pd.to_datetime(test_data["Dep_Time"]).dt.hour
# /var/folders/6y/8rwnfv1s3855864m6xpflvj00000gn/T/ipykernel_6635/2632046671.py:24: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test_data["Dep_min"] = pd.to_datetime(test_data["Dep_Time"]).dt.minute
# /var/folders/6y/8rwnfv1s3855864m6xpflvj00000gn/T/ipykernel_6635/2632046671.py:28: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test_data["Arrival_hour"] = pd.to_datetime(test_data.Arrival_Time).dt.hour
# /var/folders/6y/8rwnfv1s3855864m6xpflvj00000gn/T/ipykernel_6635/2632046671.py:29: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test_data["Arrival_min"] = pd.to_datetime(test_data.Arrival_Time).dt.minute

# %%
data_test.head()
# Out:
#    Total_Stops  Journey_day  Journey_month  Dep_hour  Dep_min  Arrival_hour  \
# 1            1           12              5         6       20            10
# 3            1           21              5         8        0            21
# 4            0           24              6        23       55             2
# 6            1           12              3         7       30            22
# 7            1            1              5        15       15            20
#
#    Arrival_min  Duration_hours  Duration_mins  Air Asia  Air India  GoAir  \
# 1           20               4              0     False      False  False
# 3            0              13              0     False      False  False
# 4           45               2             50      True      False  False
# 6           35              15              5     False       True  False
# 7           30               5             15     False      False  False
#
#    IndiGo  Multiple carriers  Multiple carriers Premium economy  SpiceJet  \
# 1    True              False                              False     False
# 3   False               True                              False     False
# 4   False              False                              False     False
# 6   False              False                              False     False
# 7    True              False                              False     False
#
#    Vistara  Vistara Premium economy  Banglore  Chennai  Delhi  Kolkata  \
# 1    False                    False     False    False  False     True
# 3    False                    False     False    False   True    False
# 4    False                    False      True    False  False    False
# 6    False                    False      True    False  False    False
# 7    False                    False     False    False  False     True
#
#    Mumbai  Banglore  Cochin  Delhi  Hyderabad  Kolkata  New Delhi
# 1   False      True   False  False      False    False      False
# 3   False     False    True  False      False    False      False
# 4   False     False   False   True      False    False      False
# 6   False     False   False  False      False    False       True
# 7   False      True   False  False      False    False      False

# %% [markdown]
# # Feature Eng

# %%
train_data.shape
# Out:
# (6827, 32)

# %%
 train_data.columns
# Out:
# Index(['Total_Stops', 'Price', 'Day_of_Journey', 'Month_of_Journey',
#        'Year_of_Journey', 'Dep_min', 'Dep_hour', 'Arr_minute', 'Arr_hour',
#        'duration_hours', 'duration_minute', 'Source_Banglore',
#        'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
#        'Destination_Banglore', 'Destination_Cochin', 'Destination_Delhi',
#        'Destination_Hyderabad', 'Destination_Kolkata', 'Destination_New Delhi',
#        'Airline_Air Asia', 'Airline_Air India', 'Airline_GoAir',
#        'Airline_IndiGo', 'Airline_Multiple carriers',
#        'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
#        'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy'],
#       dtype='object')

# %%
x = train_data.loc[:, ['Total_Stops', 'Day_of_Journey', 'Month_of_Journey',
       'Year_of_Journey', 'Dep_min', 'Dep_hour', 'Arr_minute', 'Arr_hour',
       'duration_hours', 'duration_minute', 'Source_Chennai', 'Source_Delhi',
       'Source_Kolkata', 'Source_Mumbai', 'Destination_Cochin',
       'Destination_Delhi', 'Destination_Hyderabad', 'Destination_Kolkata',
       'Destination_New Delhi', 'Airline_Air India', 'Airline_GoAir',
       'Airline_IndiGo', 'Airline_Multiple carriers',
       'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
       'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy']]

# %%
x
# Out:
#        Total_Stops  Day_of_Journey  Month_of_Journey  Year_of_Journey  \
# 0                0              24                 3             2019
# 1                2               1                 5             2019
# 3                1              12                 5             2019
# 4                1               1                 3             2019
# 5                0              24                 6             2019
# ...            ...             ...               ...              ...
# 10677            0              21                 5             2019
# 10678            0               9                 4             2019
# 10679            0              27                 4             2019
# 10681            0               1                 3             2019
# 10682            2               9                 5             2019
#
#        Dep_min  Dep_hour  Arr_minute  Arr_hour  duration_hours  \
# 0           20        22          10         1               2
# 1           50         5          15        13               7
# 3            5        18          30        23               5
# 4           50        16          35        21               4
# 5            0         9          25        11               2
# ...        ...       ...         ...       ...             ...
# 10677       55         5          35         8               2
# 10678       55        19          25        22               2
# 10679       45        20          20        23               2
# 10681       30        11          10        14               2
# 10682       55        10          15        19               8
#
#        duration_minute  Source_Chennai  Source_Delhi  Source_Kolkata  \
# 0                   50           False         False           False
# 1                   25           False         False            True
# 3                   25           False         False            True
# 4                   45           False         False           False
# 5                   25           False         False            True
# ...                ...             ...           ...             ...
# 10677               40           False         False           False
# 10678               30           False         False            True
# 10679               35           False         False            True
# 10681               40           False         False           False
# 10682               20           False          True           False
#
#        Source_Mumbai  Destination_Cochin  Destination_Delhi  \
# 0              False               False              False
# 1              False               False              False
# 3              False               False              False
# 4              False               False              False
# 5              False               False              False
# ...              ...                 ...                ...
# 10677          False               False               True
# 10678          False               False              False
# 10679          False               False              False
# 10681          False               False              False
# 10682          False                True              False
#
#        Destination_Hyderabad  Destination_Kolkata  Destination_New Delhi  \
# 0                      False                False                   True
# 1                      False                False                  False
# 3                      False                False                  False
# 4                      False                False                   True
# 5                      False                False                  False
# ...                      ...                  ...                    ...
# 10677                  False                False                  False
# 10678                  False                False                  False
# 10679                  False                False                  False
# 10681                  False                False                   True
# 10682                  False                False                  False
#
#        Airline_Air India  Airline_GoAir  Airline_IndiGo  \
# 0                  False          False            True
# 1                   True          False           False
# 3                  False          False            True
# 4                  False          False            True
# 5                  False          False           False
# ...                  ...            ...             ...
# 10677              False          False           False
# 10678              False          False           False
# 10679               True          False           False
# 10681              False          False           False
# 10682               True          False           False
#
#        Airline_Multiple carriers  Airline_Multiple carriers Premium economy  \
# 0                          False                                      False
# 1                          False                                      False
# 3                          False                                      False
# 4                          False                                      False
# 5                          False                                      False
# ...                          ...                                        ...
# 10677                      False                                      False
# 10678                      False                                      False
# 10679                      False                                      False
# 10681                      False                                      False
# 10682                      False                                      False
#
#        Airline_SpiceJet  Airline_Trujet  Airline_Vistara  \
# 0                 False           False            False
# 1                 False           False            False
# 3                 False           False            False
# 4                 False           False            False
# 5                  True           False            False
# ...                 ...             ...              ...
# 10677              True           False            False
# 10678             False           False            False
# 10679             False           False            False
# 10681             False           False             True
# 10682             False           False            False
#
#        Airline_Vistara Premium economy
# 0                                False
# 1                                False
# 3                                False
# 4                                False
# 5                                False
# ...                                ...
# 10677                            False
# 10678                            False
# 10679                            False
# 10681                            False
# 10682                            False
#
# [6827 rows x 28 columns]

# %%
y = train_data.iloc[: ,1]

# %%
y
# Out:
# 0         3897
# 1         7662
# 3         6218
# 4        13302
# 5         3873
#          ...
# 10677     3257
# 10678     4107
# 10679     4145
# 10681    12648
# 10682    11753
# Name: Price, Length: 6827, dtype: int64

# %%
# Correlation bte indepndent and deendent features
plt.figure(figsize = (18,18))
sns.heatmap(train_data.corr(), annot= True, cmap = 'RdYlGn')

plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
# ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(x, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [2.61441197e-01 1.21249836e-01 7.44914521e-02 0.00000000e+00
#  3.47398467e-02 3.32514829e-02 2.77541583e-02 3.10158438e-02
#  1.44745858e-01 2.50027293e-02 1.00405120e-03 2.88794872e-02
#  5.90417494e-03 3.33490129e-03 4.43047777e-02 1.82946089e-03
#  4.86604016e-03 1.06015544e-03 2.32159102e-02 4.00499478e-02
#  2.94291573e-03 1.70652979e-02 5.28440060e-02 2.13425752e-03
#  3.94102745e-03 1.90411766e-04 1.25483176e-02 1.92454805e-04]

# %%
#plot graph of feature importances for better visualization

plt.figure(figsize = (12,8))
feat_importances = pd.Series(selection.feature_importances_, index=x.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %%
# Fitting model using Random Forest
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor()
reg_rf.fit(X_train, y_train)
y_pred = reg_rf.predict(X_test)
reg_rf.score(X_train, y_train)
sns.distplot(y_test-y_pred)
plt.show()
# Out:
# /var/folders/6y/8rwnfv1s3855864m6xpflvj00000gn/T/ipykernel_6635/1796520086.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_pred)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 754.6437870276178
# MSE: 2641796.3494799836
# RMSE: 1625.3603752645083

# %%
# RMSE/(max(DV)-min(DV))

2090.5509/(max(y)-min(y))
# Out:
# 0.05935018453327277

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.8206570209270524

# %%
import joblib

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)

# Save the model using joblib
joblib.dump(model, 'model_packet')
# Out:
# ['final_rf.pkl']
